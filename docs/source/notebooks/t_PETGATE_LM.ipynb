# %% [markdown]
# # GATE: Listmode, TOF, Primaries Only

# %% [markdown]
# The following example provides a complete example of a PET reconstruction from data generated from the GATE Monte Carlo program, including the computation of a normalization factor from a normalization scan. If you want to gain access to these files, please email me at `lukepolson@outlook.com`

# %%
import torch
import pytomography
from pytomography.metadata import ObjectMeta, PETLMProjMeta, PETTOFMeta
from pytomography.projectors.PET import PETLMSystemMatrix
from pytomography.algorithms import OSEM
from pytomography.io.PET import gate
from pytomography.likelihoods import PoissonLogLikelihood
import os
from pytomography.transforms.shared import GaussianFilter
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# %%
# Change this
path = '/disk1/pet_mri_scan/'

# %% [markdown]
# PET listmode reconstruction (with no scatter/randoms) via MLEM can be written as
#
# $$\hat{f}^{n+1} = \left[\frac{1}{\tilde{H}^T \eta \mu 1} H^T \left(\frac{1}{H\hat{f}^{n}}\right)\right] \hat{f}^{n}$$
#
# * The system matrix $H$ projects an object to all detected LORs via ray-tracing.
# * The "complete" system matrix $\tilde{H}$ projects an object to all possible valid LORs of the scanner via ray-tracing.
# * The attenuation correction factor $\mu$ depends on an attenuation map obtained via a CT/MRI scan.
# * The normalization $\eta$ is slightly more complicated: depending on the geomtrical arrangement of crystals as well as the efficiency of all crystals.
#
# In this tutorial, we'll look at data from a simulation that was "attenuation-free" so $\mu=1$ everywhere. We still, however, need $\eta$ if we are to reconstruct PET data from this scanner. We'll start by obtaining $\eta$ via a "simulated normalization scan"; this was obtained by simulating acquisition of a thin cylindrical shell with large radius. Functionality exists in PyTomography for obtaining $\eta$ from such a scan.

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### Normalization Data

# %% [markdown]
# **The cell below only needs to be ran once**, and may take a long time, as it requires opening and parsing through all the ROOT files corresponding to the normalization scan. Once it is ran, the normalization $\eta$ will be saved to a file. This particular calibration scan was done using a thin cylindrical shell. We can compute $\eta$ using a particular function in the gate functionality of PyTomography. Then we save it as a `numpy` file for easy access in the next part. For this we need
#
# * `mean_interaction_depth`: The mean interaction depth of photons in the crystals in mm
# * `cylinder_radius`: The radius of the thin cylindrical shell used for calibration
# * `macro_path`: The path to the macro used in GATE to generate the scanner geometry

# %%
normalization_paths = [os.path.join(path, f'normalization_scan/mMR_Norm_{i}.root') for i in range(1,37)]

mean_interaction_depth = 9 # mm
cylinder_radius = 320 # mm (radius of calibration cylindrical shell)
macro_path = os.path.join(path, 'mMR_Geometry.mac')

eta = gate.get_eta_cylinder_calibration(
    normalization_paths,
    macro_path,
    cylinder_radius=cylinder_radius,
    include_randoms=False, #used to ignore random events in simulation
    mean_interaction_depth=mean_interaction_depth)

torch.save(eta, os.path.join(path, 'norm_factor_lm.pt'))
# Out:
# /data/home/gpuvmadm/PyTomography/src/pytomography/io/PET/gate.py:271: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   scanner_LUT = torch.tensor(get_scanner_LUT(info))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 cylinder_radius = 320 # mm (radius of calibration cylindrical shell)
#       5 macro_path = os.path.join(path, 'mMR_Geometry.mac')
# ----> 7 eta = gate.get_eta_cylinder_calibration(
#       8     normalization_paths,
#       9     macro_path,
#      10     cylinder_radius=cylinder_radius,
#      11     include_randoms=False, #used to ignore random events in simulation
#      12     mean_interaction_depth=mean_interaction_depth)
#      14 torch.save(eta, os.path.join(path, 'norm_factor_lm.pt'))
#
# File /data/home/gpuvmadm/PyTomography/src/pytomography/io/PET/gate.py:284, in get_eta_cylinder_calibration(paths, mac_file, cylinder_radius, include_randoms, mean_interaction_depth)
#     282 for path in paths:
#     283     with uproot.open(path) as f:
# --> 284         vals = get_symmetry_histogram_from_ROOTfile(f, info, include_randoms=include_randoms)
#     285         histo += torch.histogramdd(vals.to(torch.float32), bin_edges)[0]
#     286 vals_all_pairs = get_symmetry_histogram_all_combos(info)
#
# File /data/home/gpuvmadm/PyTomography/src/pytomography/io/PET/gate.py:208, in get_symmetry_histogram_from_ROOTfile(f, info, substr, include_randoms)
#     207 def get_symmetry_histogram_from_ROOTfile(f, info, substr='Coincidences', include_randoms=True) -> torch.tensor:
# --> 208     ids1_trans_crystal, ids1_axial_crystal, ids1_trans_submodule, ids1_axial_submodule, ids1_trans_module, ids1_axial_module, ids1_trans_rsector, ids1_axial_rsector = get_axial_trans_ids_from_ROOT(f, info, 0, substr= substr)
#     209     ids2_trans_crystal, ids2_axial_crystal, ids2_trans_submodule, ids2_axial_submodule, ids2_trans_module, ids2_axial_module, ids2_trans_rsector, ids2_axial_rsector = get_axial_trans_ids_from_ROOT(f, info, 1, substr= substr)
#     210     ids_trans_crystal = torch.vstack([ids1_trans_crystal, ids2_trans_crystal])
#
# File /data/home/gpuvmadm/PyTomography/src/pytomography/io/PET/gate.py:125, in get_axial_trans_ids_from_ROOT(f, info, j, substr, sort_by_detector_ids)
#     123 else:
#     124     idx_str = f'{j+1}'
# --> 125 ids_rsector = torch.tensor(f[substr][f'rsectorID{idx_str}'].array(library="np"))
#     126 ids_module = torch.tensor(f[substr][f'moduleID{idx_str}'].array(library="np"))
#     127 ids_submodule = torch.tensor(f[substr][f'submoduleID{idx_str}'].array(library="np"))
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/behaviors/TBranch.py:1821, in TBranch.array(self, interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc)
#    1818                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#    1820 interp_options = {"ak_add_doc": ak_add_doc}
# -> 1821 _ranges_or_baskets_to_arrays(
#    1822     self,
#    1823     ranges_or_baskets,
#    1824     branchid_interpretation,
#    1825     entry_start,
#    1826     entry_stop,
#    1827     decompression_executor,
#    1828     interpretation_executor,
#    1829     library,
#    1830     arrays,
#    1831     False,
#    1832     interp_options,
#    1833 )
#    1835 _fix_asgrouped(
#    1836     arrays,
#    1837     expression_context,
#    (...)
#    1841     ak_add_doc,
#    1842 )
#    1844 if array_cache is not None:
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/behaviors/TBranch.py:3140, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3138 if isinstance(obj, uproot.source.chunk.Chunk):
#    3139     args = range_args[(obj.start, obj.stop)]
# -> 3140     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3142 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
#    3143     interpretation_executor.submit(basket_to_array, obj)
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/source/futures.py:104, in TrivialExecutor.submit(self, task, *args, **kwargs)
#     100 def submit(self, task, /, *args, **kwargs):
#     101     """
#     102     Immediately runs ``task(*args)``.
#     103     """
# --> 104     return TrivialFuture(task(*args, **kwargs))
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/behaviors/TBranch.py:3062, in _ranges_or_baskets_to_arrays.<locals>.chunk_to_basket(chunk, branch, basket_num)
#    3060 try:
#    3061     cursor = uproot.source.cursor.Cursor(chunk.start)
# -> 3062     basket = uproot.models.TBasket.Model_TBasket.read(
#    3063         chunk,
#    3064         cursor,
#    3065         {"basket_num": basket_num},
#    3066         hasbranches._file,
#    3067         hasbranches._file,
#    3068         branch,
#    3069     )
#    3070     original_index = range_original_index[(chunk.start, chunk.stop)]
#    3071     if update_ranges_or_baskets:
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/model.py:858, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     849     if forth_stash is not None:
#     850         forth_obj.add_node(
#     851             "model828",
#     852             forth_stash.get_attrs(),
#    (...)
#     855             {},
#     856         )
# --> 858     self.read_members(chunk, cursor, context, file)
#     859     self.hook_after_read_members(
#     860         chunk=chunk, cursor=cursor, context=context, file=file
#     861     )
#     863 self.check_numbytes(chunk, cursor, context)
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/models/TBasket.py:228, in Model_TBasket.read_members(self, chunk, cursor, context, file)
#     218 assert isinstance(self._parent, uproot.behaviors.TBranch.TBranch)
#     219 self._basket_num = context.get("basket_num")
#     221 (
#     222     self._members["fNbytes"],
#     223     self._key_version,
#     224     self._members["fObjlen"],
#     225     self._members["fDatime"],
#     226     self._members["fKeylen"],
#     227     self._members["fCycle"],
# --> 228 ) = cursor.fields(chunk, _tbasket_format1, context)
#     230 # skip the class name, name, and title
#     231 cursor.move_to(
#     232     self._cursor.index + self._members["fKeylen"] - _tbasket_format2.size - 1
#     233 )
#
# File /data/anaconda/envs/pytomo_install_test/lib/python3.11/site-packages/uproot/source/cursor.py:201, in Cursor.fields(self, chunk, format, context, move)
#     199 if move:
#     200     self._index = stop
# --> 201 return format.unpack(chunk.get(start, stop, self, context))
#
# KeyboardInterrupt:

# %% [markdown]
# Once the above has ran once, we can open the weights as follows:

# %%
weights_sensitivity = torch.load(os.path.join(path, 'norm_factor_lm.pt'))

# %% [markdown]
# ### Detection Data

# %% [markdown]
# **The following cell only needs to be ran once**. The purpose is to convert all the acquired GATE data in ROOT files to a numpy array for easy access. It may take awhile to run. It saves all the detector IDs corresponding to every coincidence event in the scan. It also bins the time of flight.

# %%
speed_of_light = 0.3 #mm/ps
fwhm_tof_resolution = 550 * speed_of_light / 2 #ps to position along LOR
TOF_range = 1000 * speed_of_light #ps to position along LOR (full range)
num_tof_bins = 5
tof_meta = PETTOFMeta(num_tof_bins, TOF_range, fwhm_tof_resolution, n_sigmas=3)

# Get detector IDs from GATE file
paths = [os.path.join(path, f'gate_simulation/no_atten/f{i}.root') for i in range(1, 19)]
macro_path = os.path.join(path, 'mMR_Geometry.mac')
detector_ids = gate.get_detector_ids_from_root(
    paths,
    macro_path,
    include_randoms=False,
    tof_meta=tof_meta)
torch.save(detector_ids, os.path.join(path, 'detector_ids.pt'))

# %% [markdown]
# Once the cell above has been run, data can be loaded much faster

# %%
detector_ids = torch.load(os.path.join(path, 'detector_ids.pt'))

# %% [markdown]
# ## Reconstruction

# %% [markdown]
# All the information about the scanner is contained in the `info` instance. `info` is intended to be data source independent

# %%
info = gate.get_detector_info(path = os.path.join(path, 'mMR_Geometry.mac'), mean_interaction_depth=9)
info
# Out:
# {'min_rsector_difference': 0,
#  'crystal_length': 20.0,
#  'radius': 337.0,
#  'crystalTransNr': 8,
#  'crystalTransSpacing': 4.0,
#  'crystalAxialNr': 8,
#  'crystalAxialSpacing': 4.0,
#  'submoduleAxialNr': 1,
#  'submoduleAxialSpacing': 0,
#  'submoduleTransNr': 1,
#  'submoduleTransSpacing': 0,
#  'moduleTransNr': 1,
#  'moduleTransSpacing': 0.0,
#  'moduleAxialNr': 8,
#  'moduleAxialSpacing': 32.25,
#  'rsectorTransNr': 56,
#  'rsectorAxialNr': 1,
#  'NrCrystalsPerRing': 448,
#  'NrRings': 64}

# %% [markdown]
# Now it's time to specify the reconstruction parameters. Firstly we create the object space:

# %%
object_meta = ObjectMeta(
    dr=(2,2,2), #mm
    shape=(128,128,96) #voxels
)

# %% [markdown]
# Now we create the time of flight metadata based on how we want to arrange the time of flight bins.

# %%
speed_of_light = 0.3 #mm/ps
fwhm_tof_resolution = 550 * speed_of_light / 2 #ps to position along LOR
TOF_range = 1000 * speed_of_light #ps to position along LOR (full range)
num_tof_bins = 5
tof_meta = PETTOFMeta(num_tof_bins, TOF_range, fwhm_tof_resolution, n_sigmas=3)

# %% [markdown]
# Now we'll create the projection metadata. We'll specify that weights used for computing the sensitivity image $\tilde{H}^T 1$ are loaded from path (in this case, from the `eta.npy` image). Since no attenuation is used in this simulation, `eta`

# %%
proj_meta = PETLMProjMeta(
    detector_ids,
    info,
    tof_meta=tof_meta,
    weights_sensitivity=weights_sensitivity
    )

# %% [markdown]
# From the projection metadata we can create the system matrix, which maps from object space to projection space. For listmode PET, projection space corresponds to 1D vectors with number of entries equal to the number of detected events.
#
# * We'll add 2mm gaussian blurring for PSF modeling, to demonstrate the capabilities of the library

# %%
psf_transform = GaussianFilter(2) # 2mm gaussian blurring
system_matrix = PETLMSystemMatrix(
    object_meta,
    proj_meta,
    obj2obj_transforms = [psf_transform],
    N_splits=8,
)

# %% [markdown]
# Now we'll create the likelihood. When reconstructing listmode data, its important to pass `torch.tensor([1.])` as the projections argument.

# %%
likelihood = PoissonLogLikelihood(
    system_matrix,
    projections=torch.tensor([1.]).to(pytomography.device)
)

# %% [markdown]
# We'll reconstruct the data using OSEM.

# %%
recon_algorithm = OSEM(likelihood)

# %% [markdown]
# Now we reconstruct for 2 iterations with 28 subsets

# %%
recon = recon_algorithm(n_iters=2, n_subsets=28)

# %% [markdown]
# And plot some slices of the reconstruction:

# %%
fig, ax = plt.subplots(1,3,figsize=(12,4))
plt.subplot(131)
plt.pcolormesh(recon[0,48,16:-16].cpu().T, cmap='magma', shading='gouraud')
plt.axis('off')
plt.subplot(132)
plt.pcolormesh(recon[0,16:-16,64].cpu().T, cmap='magma', shading='gouraud')
plt.axis('off')
plt.subplot(133)
plt.pcolormesh(recon[0,:,:,48].cpu().T, cmap='magma', shading='gouraud')
plt.axis('off')
fig.tight_layout()
plt.show()

# %% [markdown]
# The data can be saved to nifti for external viewing in alternative software. This is a basic way of doing that:

# %%
affine=np.eye(4); affine[-1,-1] = 0
recon_nib = nib.Nifti1Image(recon[0].cpu().numpy(), affine=affine)
nib.save(recon_nib, os.path.join(path, 'petgate_example_recon.nii.gz'))
